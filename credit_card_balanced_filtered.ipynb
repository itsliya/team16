# %% [markdown]
# <a href="https://colab.research.google.com/github/itsliya/team16/blob/main/credit_card_balanced_filtered.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Home Credit Default Risk](https://www.kaggle.com/competitions/home-credit-default-risk/data?select=HomeCredit_columns_description.csv)

# %% [markdown]
# # Installing Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credit_card_balance = pd.read_csv('/content/drive/MyDrive/Data X Personal Folder/Neural_Networks/credit_card_balance.csv',encoding='unicode_escape')

# %% [markdown]
# # Cleaning credit_card_balance.csv

# %%
credit_card_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3840312 entries, 0 to 3840311
# Data columns (total 23 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   SK_ID_PREV                  int64
#  1   SK_ID_CURR                  int64
#  2   MONTHS_BALANCE              int64
#  3   AMT_BALANCE                 float64
#  4   AMT_CREDIT_LIMIT_ACTUAL     int64
#  5   AMT_DRAWINGS_ATM_CURRENT    float64
#  6   AMT_DRAWINGS_CURRENT        float64
#  7   AMT_DRAWINGS_OTHER_CURRENT  float64
#  8   AMT_DRAWINGS_POS_CURRENT    float64
#  9   AMT_INST_MIN_REGULARITY     float64
#  10  AMT_PAYMENT_CURRENT         float64
#  11  AMT_PAYMENT_TOTAL_CURRENT   float64
#  12  AMT_RECEIVABLE_PRINCIPAL    float64
#  13  AMT_RECIVABLE               float64
#  14  AMT_TOTAL_RECEIVABLE        float64
#  15  CNT_DRAWINGS_ATM_CURRENT    float64
#  16  CNT_DRAWINGS_CURRENT        int64
#  17  CNT_DRAWINGS_OTHER_CURRENT  float64
# ...

# %% [markdown]
# ## Drop irrelevant features

# %% [markdown]
# No irrelevant features

# %% [markdown]
# # Categorical Variables

# %% [markdown]
# Create list of Categorical Variables

# %%
L = [col for col in credit_card_balance.columns if credit_card_balance[col].dtype == object]

for col in L:
    print(col, 'has ',credit_card_balance[col].nunique(), ' distinct values.')
# Out:
# NAME_CONTRACT_STATUS has  7  distinct values.

# %% [markdown]
# Find which values these have

# %%
credit_card_balance["NAME_CONTRACT_STATUS"].unique()
# Out:
# array(['Active', 'Completed', 'Demand', 'Signed', 'Sent proposal',
#        'Refused', 'Approved'], dtype=object)

# %% [markdown]
# There is a need to drop it. It is only one categorical variable with few values

# %% [markdown]
# # Correlations Between Independent Variables

# %%
plt.figure(figsize=(10,10))
sns.heatmap(credit_card_balance.corr())

# %% [markdown]
# AMT_BALANCE, AMT_DRAWINGS_CURRENT, AMT_INST_MIN_REGULARITY, AMT_TOTAL_RECEIVABLE, AMT_RECEIVABLE, AMT_RECEIVABLE_PRINCIPAL, CNT_DRAWINGS_POS_CURRENT, are the variables with highest correlations

# %%
credit_card_balance.drop(['AMT_BALANCE','AMT_DRAWINGS_CURRENT','AMT_INST_MIN_REGULARITY','AMT_TOTAL_RECEIVABLE','AMT_RECIVABLE','AMT_RECEIVABLE_PRINCIPAL','CNT_DRAWINGS_POS_CURRENT'],axis = 1, inplace = True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(credit_card_balance.corr())

# %% [markdown]
# CNT_DRAWING_ATM_CURRENT, CNT_DRAWINGS_CURRENT,  AMT_DRAWINGS_OTHER_CURRENT and AMT_PAYMENT_TOTAL_CURRENT

# %%
credit_card_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3840312 entries, 0 to 3840311
# Data columns (total 16 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   SK_ID_PREV                  int64
#  1   SK_ID_CURR                  int64
#  2   MONTHS_BALANCE              int64
#  3   AMT_CREDIT_LIMIT_ACTUAL     int64
#  4   AMT_DRAWINGS_ATM_CURRENT    float64
#  5   AMT_DRAWINGS_OTHER_CURRENT  float64
#  6   AMT_DRAWINGS_POS_CURRENT    float64
#  7   AMT_PAYMENT_CURRENT         float64
#  8   AMT_PAYMENT_TOTAL_CURRENT   float64
#  9   CNT_DRAWINGS_ATM_CURRENT    float64
#  10  CNT_DRAWINGS_CURRENT        int64
#  11  CNT_DRAWINGS_OTHER_CURRENT  float64
#  12  CNT_INSTALMENT_MATURE_CUM   float64
#  13  NAME_CONTRACT_STATUS        object
#  14  SK_DPD                      int64
#  15  SK_DPD_DEF                  int64
# dtypes: float64(8), int64(7), object(1)
# memory usage: 468.8+ MB

# %%
credit_card_balance.drop(['CNT_DRAWINGS_ATM_CURRENT','CNT_DRAWINGS_CURRENT','AMT_DRAWINGS_OTHER_CURRENT','AMT_PAYMENT_TOTAL_CURRENT'],axis = 1, inplace = True)
plt.figure(figsize=(10,10))
sns.heatmap(credit_card_balance.corr())

# %%
credit_card_balance.shape
# Out:
# (3840312, 12)

# %%
#credit_card_balance.to_csv("credit_card_balance_filtered",compression='gzip')
